# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('laptop_prices.csv')

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches  Ram     OS  Weight  Price_euros  \
# 0   Apple  MacBook Pro  Ultrabook    13.3    8  macOS    1.37      1339.69
# 1   Apple  Macbook Air  Ultrabook    13.3    8  macOS    1.34       898.94
# 2      HP       250 G6   Notebook    15.6    8  No OS    1.86       575.00
# 3   Apple  MacBook Pro  Ultrabook    15.4   16  macOS    1.83      2537.45
# 4   Apple  MacBook Pro  Ultrabook    13.3    8  macOS    1.37      1803.60
#
#      Screen  ScreenW  ...  RetinaDisplay CPU_company CPU_freq      CPU_model  \
# 0  Standard     2560  ...            Yes       Intel      2.3        Core i5
# 1  Standard     1440  ...             No       Intel      1.8        Core i5
# 2   Full HD     1920  ...             No       Intel      2.5  Core i5 7200U
# 3  Standard     2880  ...            Yes       Intel      2.7        Core i7
# 4  Standard     2560  ...            Yes       Intel      3.1        Core i5
#
# ...

# %%
df.dtypes
# Out:
# Company                  object
# Product                  object
# TypeName                 object
# Inches                  float64
# Ram                       int64
# OS                       object
# Weight                  float64
# Price_euros             float64
# Screen                   object
# ScreenW                   int64
# ScreenH                   int64
# Touchscreen              object
# IPSpanel                 object
# RetinaDisplay            object
# CPU_company              object
# CPU_freq                float64
# CPU_model                object
# PrimaryStorage            int64
# SecondaryStorage          int64
# PrimaryStorageType       object
# SecondaryStorageType     object
# GPU_company              object
# GPU_model                object
# dtype: object

# %%
df.shape
# Out:
# (1275, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1275 entries, 0 to 1274
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Company               1275 non-null   object
#  1   Product               1275 non-null   object
#  2   TypeName              1275 non-null   object
#  3   Inches                1275 non-null   float64
#  4   Ram                   1275 non-null   int64
#  5   OS                    1275 non-null   object
#  6   Weight                1275 non-null   float64
#  7   Price_euros           1275 non-null   float64
#  8   Screen                1275 non-null   object
#  9   ScreenW               1275 non-null   int64
#  10  ScreenH               1275 non-null   int64
#  11  Touchscreen           1275 non-null   object
#  12  IPSpanel              1275 non-null   object
#  13  RetinaDisplay         1275 non-null   object
#  14  CPU_company           1275 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Company                 0
# Product                 0
# TypeName                0
# Inches                  0
# Ram                     0
# OS                      0
# Weight                  0
# Price_euros             0
# Screen                  0
# ScreenW                 0
# ScreenH                 0
# Touchscreen             0
# IPSpanel                0
# RetinaDisplay           0
# CPU_company             0
# CPU_freq                0
# CPU_model               0
# PrimaryStorage          0
# SecondaryStorage        0
# PrimaryStorageType      0
# SecondaryStorageType    0
# GPU_company             0
# GPU_model               0
# dtype: int64

# %%
df.describe()
# Out:
#             Inches          Ram       Weight  Price_euros      ScreenW  \
# count  1275.000000  1275.000000  1275.000000  1275.000000  1275.000000
# mean     15.022902     8.440784     2.040525  1134.969059  1900.043922
# std       1.429470     5.097809     0.669196   700.752504   493.346186
# min      10.100000     2.000000     0.690000   174.000000  1366.000000
# 25%      14.000000     4.000000     1.500000   609.000000  1920.000000
# 50%      15.600000     8.000000     2.040000   989.000000  1920.000000
# 75%      15.600000     8.000000     2.310000  1496.500000  1920.000000
# max      18.400000    64.000000     4.700000  6099.000000  3840.000000
#
#            ScreenH     CPU_freq  PrimaryStorage  SecondaryStorage
# count  1275.000000  1275.000000     1275.000000       1275.000000
# mean   1073.904314     2.302980      444.517647        176.069020
# std     283.883940     0.503846      365.537726        415.960655
# ...

# %%
Company = df['Company'].value_counts()
Company
# Out:
# Company
# Dell         291
# Lenovo       289
# HP           268
# Asus         152
# Acer         101
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
df['Company'].value_counts().plot(kind= 'bar')
# Out:
# <Axes: xlabel='Company'>

# %%
OS = df['OS'].value_counts()
OS
# Out:
# OS
# Windows 10      1048
# No OS             66
# Linux             58
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
df['OS'].value_counts().plot(kind= 'bar', x = df['OS'])
# Out:
# <Axes: xlabel='OS'>

# %%
Touchscreen = df['Touchscreen'].value_counts()
Touchscreen

# %%
df['Touchscreen'].value_counts().plot(kind= 'pie', autopct = '%.2f%%',title= 'TouchScreen')
# Out:
# <Axes: title={'center': 'TouchScreen'}, ylabel='count'>

# %%
Ram = df['Ram'].value_counts()
Ram
# Out:
# Ram
# 8     613
# 4     367
# 16    198
# 6      35
# 12     25
# 32     17
# 2      16
# 24      3
# 64      1
# Name: count, dtype: int64

# %%
df['Ram'].value_counts().plot(kind= 'bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
CPU_company = df['CPU_company'].value_counts()
CPU_company
# Out:
# CPU_company
# Intel      1214
# AMD          60
# Samsung       1
# Name: count, dtype: int64

# %%
df['CPU_company'].value_counts().plot(kind = 'pie', autopct = '%.2f%%', title = 'CPU_company')
# Out:
# <Axes: title={'center': 'CPU_company'}, ylabel='count'>

# %%
GPU_company = df['GPU_company'].value_counts()
GPU_company
# Out:
# GPU_company
# Intel     704
# Nvidia    396
# AMD       174
# ARM         1
# Name: count, dtype: int64

# %%
df['GPU_company'].value_counts().plot(kind = 'pie', autopct = '%.2f%%', title = 'GPU_Company')
# Out:
# <Axes: title={'center': 'GPU_Company'}, ylabel='count'>

# %%
IPSpanel = df['IPSpanel'].value_counts()
IPSpanel
# Out:
# IPSpanel
# No     918
# Yes    357
# Name: count, dtype: int64

# %%
df['IPSpanel'].value_counts().plot(kind= 'pie', autopct = '%.f%%')
# Out:
# <Axes: ylabel='count'>

# %%
Inches = df['Inches'].value_counts()
Inches
# Out:
# Inches
# 15.6    647
# 14.0    193
# 17.3    164
# 13.3    160
# 12.5     39
# 11.6     31
# 12.0      6
# 13.5      6
# 13.9      6
# 12.3      5
# 10.1      4
# 15.4      4
# 15.0      4
# 13.0      2
# 18.4      1
# 17.0      1
# 14.1      1
# 11.3      1
# Name: count, dtype: int64

# %%
df['Inches']. value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Inches'>

# %%
PrimaryStorageType = df['PrimaryStorageType'].value_counts()
PrimaryStorageType
# Out:
# PrimaryStorageType
# SSD              837
# HDD              359
# Flash Storage     71
# Hybrid             8
# Name: count, dtype: int64

# %%
df['PrimaryStorageType'].value_counts().plot(kind= 'pie', autopct = '%2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
screen_counts = df['Screen'].value_counts()
screen_counts
# Out:
# Screen
# Full HD        835
# Standard       369
# 4K Ultra HD     43
# Quad HD+        28
# Name: count, dtype: int64

# %%
df['Screen'].value_counts().plot(kind= 'bar')
# Out:
# <Axes: xlabel='Screen'>

# %%
SecondaryStorageType = df['SecondaryStorageType'].value_counts()
SecondaryStorageType
# Out:
# SecondaryStorageType
# No        1067
# HDD        202
# SSD          4
# Hybrid       2
# Name: count, dtype: int64

# %%
df['SecondaryStorageType'].value_counts().plot(kind= 'bar')
# Out:
# <Axes: xlabel='SecondaryStorageType'>

# %%
avg_os_price = df.groupby('OS')['Price_euros'].mean().sort_values(ascending=False)

avg_os_price
# Out:
# OS
# macOS           1749.630769
# Windows 7       1686.651333
# Windows 10 S    1286.480000
# Mac OS X        1262.871250
# Windows 10      1180.684065
# Linux            621.867069
# No OS            587.973333
# Chrome OS        553.585185
# Android          434.000000
# Name: Price_euros, dtype: float64

# %%
plt.figure(figsize= (10,8))
sns.boxplot(x = df['OS'], y = df['Price_euros'])
plt.title('OS VS CPU_frequency')
plt.show()

# %%
avg_Typename_price = df.groupby('TypeName')['Price_euros'].mean().sort_values(ascending=False)

avg_Typename_price
# Out:
# TypeName
# Workstation           2280.358966
# Gaming                1731.380634
# Ultrabook             1556.676031
# 2 in 1 Convertible    1289.714530
# Notebook               788.744781
# Netbook                673.382609
# Name: Price_euros, dtype: float64

# %%
plt.figure(figsize= (10,8))
sns.barplot(x = df['TypeName'], y= df['Price_euros'])
plt.title('Price by TypeName')
plt.show()

# %%
CPU_company_Price = df.groupby('CPU_company')['Price_euros'].mean().sort_values(ascending=False)

CPU_company_Price
# Out:
# CPU_company
# Intel      1163.728929
# Samsung     659.000000
# AMD         560.993833
# Name: Price_euros, dtype: float64

# %%
plt.figure(figsize= (10,8))
sns.barplot(x = df['CPU_company'], y= df['Price_euros'])
plt.title('Price by CPU company')
plt.show()

# %%
GPU_company_Price = df.groupby('GPU_company')['Price_euros'].mean().sort_values(ascending=False)

GPU_company_Price
# Out:
# GPU_company
# Nvidia    1496.745101
# Intel     1020.367713
# AMD        778.026552
# ARM        659.000000
# Name: Price_euros, dtype: float64

# %%
plt.figure(figsize= (10,8))
sns.barplot(x = df['GPU_company'], y= df['Price_euros'])
plt.title('Price by GPU Company')
plt.show()

# %%
avg_touchscreen_price = df.groupby('Touchscreen')['Price_euros'].mean().sort_values(ascending=False)

avg_touchscreen_price
# Out:
# Touchscreen
# Yes    1453.118085
# No     1079.944204
# Name: Price_euros, dtype: float64

# %%
plt.figure(figsize= (10,8))
sns.barplot(x = df['Touchscreen'], y= df['Price_euros'], hue= df['Screen'])
plt.title('Price by Touchscreen')
plt.show()

# %%
OS_price = df.groupby('OS')['Price_euros'].mean().sort_values(ascending=False)

OS_price
# Out:
# OS
# macOS           1749.630769
# Windows 7       1686.651333
# Windows 10 S    1286.480000
# Mac OS X        1262.871250
# Windows 10      1180.684065
# Linux            621.867069
# No OS            587.973333
# Chrome OS        553.585185
# Android          434.000000
# Name: Price_euros, dtype: float64

# %%
plt.figure(figsize= (10,8))
sns.barplot(x = df['OS'], y= df['Price_euros'], hue= df['Touchscreen'])
plt.title('Price by OS')
plt.show()

# %%
avg_Primarystorage_price = df.groupby('PrimaryStorage')['Price_euros'].mean().sort_values(ascending=False)

avg_Primarystorage_price
# Out:
# PrimaryStorage
# 240     3100.000000
# 8       2249.000000
# 512     1944.587647
# 256     1333.326535
# 180     1098.600000
# 128     1011.280171
# 508     1002.000000
# 1024     841.758750
# 2048     648.710625
# 500      640.090726
# 64       556.543333
# 32       309.280233
# 16       305.380000
# Name: Price_euros, dtype: float64

# %%
plt.figure(figsize= (10,8))
sns.barplot(x = df['PrimaryStorage'], y=df['Price_euros'], hue= df['SecondaryStorage'])
plt.title('Price by Primary storage')
plt.show()

# %%
avg_RetinaDisplay_price = df.groupby('RetinaDisplay')['Price_euros'].mean().sort_values(ascending=False)

avg_RetinaDisplay_price
# Out:
# RetinaDisplay
# Yes    1657.854706
# No     1127.903037
# Name: Price_euros, dtype: float64

# %%
plt.figure(figsize= (10,8))
sns.barplot(x= df['RetinaDisplay'], y= df['Price_euros'], hue= df['PrimaryStorage'])
plt.title('Price by Retina display')
plt.show()

# %%
avg_CPU_freq_price = df.groupby('CPU_freq')['Price_euros'].mean().sort_values(ascending=False)

avg_CPU_freq_price
# Out:
# CPU_freq
# 3.10    2914.200000
# 2.90    2656.657895
# 2.80    1764.089879
# 1.30    1736.516667
# 3.20    1695.000000
# 2.60    1668.983919
# 1.20    1605.693333
# 1.90    1452.980000
# 2.70    1421.869817
# 1.80    1179.231538
# 2.30    1033.539070
# 2.50    1003.856737
# 3.00     897.046842
# 2.40     822.513200
# 2.20     745.088182
# 1.60     708.667823
# 0.90     699.000000
# 3.60     684.714000
# 2.10     665.333333
# 1.00     603.000000
# 2.00     497.492093
# 1.10     424.944151
# 1.44     319.071667
# 1.50     296.999000
# 1.92     265.000000
# Name: Price_euros, dtype: float64

# %%
sns.scatterplot(data=df, x= df['CPU_freq'], y = df['Ram'], hue= df['OS'])
# Out:
# <Axes: xlabel='CPU_freq', ylabel='Ram'>
